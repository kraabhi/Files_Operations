# %%
import os

os.chdir("C:\\Users\\admin\\Documents\\Cax\\Contest_characters\\train")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\admin\\Documents\\Cax\\Contest_characters\\train'

# %%
import os
import subprocess
import cv2
import numpy as np
os.getcwd()

# Lets change working directory to the pictures folder
os.chdir("C:/Users/admin/Documents/Cax/Contest_characters/train")

path_train = "C:/Users/admin/Documents/Cax/Contest_characters/train"
file_train = os.listdir(path_train)
print(file_train)
# Out:
# ['angrybirds', 'Baloo', 'Bart simpson', 'ben', 'bulbasaur', 'charizard', 'Charlie brown', 'charmander', 'Chicken_little', 'Cinderella', 'darth_vader', 'disney_princes', 'donald_duck', 'Godzilla', 'Goku', 'goofy', 'han-solo', 'harry_potter', 'hellokitty', 'itachi', 'John_Cena', 'jojosiwa', 'kakashi', 'marilyn_monroe', 'mickey_mouse', 'minions', 'naruto', 'pikachu', 'pokemon', 'popeye', 'power_rangers', 'R2-D2', 'Roman_Reigns', 'Scoopy Doo', 'SpongeBob SquarePants', 'squirtle', 'teenage_mutant_ninja_turtles', 'Tom and Jerry', 'toy_story_characters', 'vampirina', 'vegeta', 'Winnie the poo']

# %%
# loop over the files and split the names from the extension
j =0
for i in file_train:
#     print(os.path.join(path_test,i))
    os.chdir(os.path.join(path_train,i))
    for file in os.listdir(os.curdir):
        #print (os.path.splitext(file))
        file_name, file_extension = os.path.splitext(file)
        print(file_name)
        j += 1       
        new_file_name = 'Cax_train{}.jpg'.format(j)
        print(new_file_name)
        os.rename(file, new_file_name)
# Out:
# 27948-red-1
# Cax_train1.jpg
# 31jhvdE4lYL
# Cax_train2.jpg
# 31Pub42fVHL
# Cax_train3.jpg
# 411jBJxoZKL
# Cax_train4.jpg
# 411SqvOKqwL
# Cax_train5.jpg
# 412CmQbbp8L
# Cax_train6.jpg
# 412fgIZhaTL
# Cax_train7.jpg
# 413Cx0WkQyL
# Cax_train8.jpg
# 419rsPj%2BWrL
# Cax_train9.jpg
# 41Am4kHoYhL
# Cax_train10.jpg
# 41brzQQGc7L
# Cax_train11.jpg
# 41ej5KEDMtL
# Cax_train12.jpg
# 41eRQUG3ttL
# Cax_train13.jpg
# 41fMrH8P1EL
# Cax_train14.jpg
# 41gq8qC27xL
# Cax_train15.jpg
# 41IcJyLPr2L
# Cax_train16.jpg
# 41L41es1uzL
# Cax_train17.jpg
# 41L9uVHKfxL
# Cax_train18.jpg
# 41mzN5niC6L
# Cax_train19.jpg
# 41QXEg8L2dL
# Cax_train20.jpg
# 41QyNzRqhXL
# Cax_train21.jpg
# 41U5Nf0V7aL
# Cax_train22.jpg
# 41WtU8bq%2BsL
# Cax_train23.jpg
# 41zLI0BwUwL
# Cax_train24.jpg
# 5105h7YQC-L
# Cax_train25.jpg
# 514ZkUz348L
# Cax_train26.jpg
# 518pUz-90HL
# Cax_train27.jpg
# 51aQl6dw94L
# Cax_train28.jpg
# 51Ebn4v8nYL
# Cax_train29.jpg
# 51eQopr4urL
# Cax_train30.jpg
# 51FMf4BfxAL
# Cax_train31.jpg
# ...
